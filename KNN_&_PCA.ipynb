# %% [markdown]
# #**Theoretical Questions:**

# %% [markdown]
# #1. What is K-Nearest Neighbors (KNN) and how does it work?
#  - K-Nearest Neighbors (KNN) is a supervised machine learning algorithm used for both classification and regression, though it's more commonly applied to classification tasks. It’s known for being simple, intuitive, and surprisingly effective in many scenarios.
# How KNN Works:
# 1. **Choose the number of neighbors (k)**
# 2. **Calculate distances**
# 3. **Identify the k nearest neighbors**
# 4. **Make a predictions:**
#   - **Classification**
#   - **Regression**

# %% [markdown]
# #2. What is the difference between KNN Classification and KNN Regression?
#  - Differences between KNN Classification and KNN Regression:
#  1. **KNN Classification:**
#    - It predict a category or class label (e.g., spam vs. not spam).
#    - It looks at the k nearest neighbors and assigns the class that appears most frequently among them (majority vote).
#    - Output - discrete labels like `0`, `1`, or `"cat"` , `"dog"`.
#    - Accuracy, Precision, Recall, F1-Score, ROC-AUC.
#
#  2. **KNN Regression:**
#    - It predict a continuous numerical value (e.g., house price).
#    - It takes the average (or weighted average) of the target values of the k nearest neighbors.
#    - Output - Real numbers like `42.7` or `₹1,200,000`.
#    - Mean Squared Error (MSE), Root Mean Squared Error (RMSE).

# %% [markdown]
# #3. What is the role of the distance metric in KNN?
#  - In K-Nearest Neighbors (KNN), the distance metric is the heart of the algorithm—it determines how “close” or “similar” two data points are. Since KNN makes predictions based on the k nearest neighbors, the way it measures distance directly affects which neighbors are chosen and, ultimately, the prediction itself.

# %% [markdown]
# #4. What is the Curse of Dimensionality in KNN?
#  - The Curse of Dimensionality in K-Nearest Neighbors (KNN) refers to the set of problems that arise when your data has too many features (dimensions). While more features might seem like a good thing, in high-dimensional spaces, KNN’s core assumption—that nearby points are similar—starts to break down.

# %% [markdown]
# #5. How can we choose the best value of K in KNN?
#  - Choosing the best value of K in K-Nearest Neighbors (KNN) is all about striking the right balance between bias and variance. Here's how you can approach it:
#  1. Try a Range of K Values
#  2. Use a Performance Metric
#  3. Plot the Error Rate or Accuracy
#  4. Cross-Validation

# %% [markdown]
# #6. What are KD Tree and Ball Tree in KNN?
#  - In K-Nearest Neighbors (KNN), KD Tree and Ball Tree are clever data structures used to speed up neighbor searches, especially when dealing with large datasets. Instead of comparing a query point to every single training point (which is slow), these trees organize the data in a way that allows KNN to prune large portions of the search space.

# %% [markdown]
# #7. When should you use KD Tree vs. Ball Tree?
#  - Here's how to decide between KD Tree and Ball Tree, depending on your data and use case:
# **Use KD Tree when:**
#    - Your data has low to moderate dimensionality (typically < 20 features).
#    - You’re using Euclidean distance or other axis-aligned metrics.
#    - Your dataset is well-balanced and not too skewed.
#    - You want faster build time and lower memory usage.

# %% [markdown]
# #8. What are the disadvantages of KNN?
#  - Disadvantages of KNN:
#  1. Computational Inefficiency
#  2. Curse of Dimensionality
#  3. Sensitivity to Features Scaling
#  4. Vulnerable to Irrelevant or Noisy Features
#  5. Choice of K is Tricky
#  6. Imbalanced Data Issues

# %% [markdown]
# #9. How does feature scaling affect KNN?
#  - Feature scaling plays a critical role in the performance of K-Nearest Neighbors (KNN), because KNN relies entirely on distance calculations—and if features are on different scales, the model gets skewed results.
#  1. Unequal Feature Influence
#  2. Misleading Nearest Neighbors
#  3. Poor Model Performance

# %% [markdown]
# #10. What is PCA (Principal Component Analysis)?
#  - Principal Component Analysis (PCA) is a dimensionality reduction technique used in machine learning and data analysis to simplify complex datasets while preserving as much variability (information) as possible.

# %% [markdown]
# #11. How does PCA work?
#  - How PCA Works:
# 1. Standardize the Data
# 2. Compute the Covariance Matrix
# 3. Calculate Eigenvectors and Eigenvalues
# 4. Sort and Select Top K Components
# 5. Project the Data

# %% [markdown]
# #12. What is the geometric intuition behind PCA?
#  - Geometric Intuition Behind PCA
# 1. **Data as Points in High-Dimensional Space:**
#     - Suppose your data has
# 𝑛
# n features — each data point is a vector in
# 𝑅
# 𝑛
# R
# n
#  .
#      - If you have 2D data, you can imagine the data points as a scatterplot in the plane. For 3D, you can visualize them in space. For higher dimensions, you rely on analogy.
#
#  2. **Finding a New Coordinate System:**
#    - PCA seeks a new orthogonal basis (coordinate system) aligned with the directions of maximum variance in the data.
#    - This is like rotating and re-centering your coordinate axes to "fit" the shape of your data.
#
#  3. **Principal Components as Directions of Maximal Spread:**
#    - The first principal component (PC1) is the direction (unit vector) along which the data varies the most.
#    - The second principal component (PC2) is the next orthogonal direction of maximum variance.
#
#  4. **Projection Onto Principal Axes:**
#    - Once the principal components are found, data points are projected onto them.
#    - This projection gives a lower-dimensional representation while preserving as much of the original variance (information) as possible.

# %% [markdown]
# #13. What is the difference between Feature Selection and Feature Extraction?
#  - Differences between Feature Selection and Feature Extraction:
#  1. **Feature Selection:**
#    - It chooses a subset of the original features without changing them.
#    - It keeps only the most relevant features and discard the rest.
#    - It is having techniques like filter methods (e.g., correlation, chi-square), wrapper methods (e.g., recursive feature elimination), embedded methods (e.g., Lasso).
#
#  2. **Feature Extraction:**
#    - It transforms original features into new ones using a function or algorithm.
#    - It creates informative, reduced  representatives that capture the underlying structure.
#    - It is having techniques like PCA, LDA, autoencoders.

# %% [markdown]
# #14. What are Eigenvalues and Eigenvectors in PCA?
#  - Eigenvectors, these are define the directions (axes) in the feature space along which the data varies the most. In PCA, these directions become the principal components.
#
#  - Eigenvalues, these tell us how much variance(i.e. information) is captured along each eigenvector. The larger the eigenvalue, the more important that direction is.

# %% [markdown]
# #15. How do you decide the number of components to keep in PCA?
#  - Here are the most common and effective strategies:
#  1. Explained Variance Threshold
#  2. Scree Plot (Elbow Method)
#  3. Kaiser's Rule
#  4. Permutation Test
#  5. Cross-Validation

# %% [markdown]
# #16. Can PCA be used for classification?
#  - Why Use PCA Before Classification?
#     - Dimensionality Reduction: Reduces the number of features, which can help avoid overfitting and speed up training.
#     - Noise Filtering: Removes low-variance components that may represent noise.
#     - Improved Class Separation: Sometimes, projecting data into PCA space reveals clearer class boundaries.

# %% [markdown]
# #17. What are the limitations of PCA?
#  - Principal Component Analysis (PCA) is a powerful tool for dimensionality reduction, but it’s not without its quirks. Here are the key limitations you should be aware of:
#  1. Loss of Interpretability
#  2. Information Loss
#  3. Sensitive to Feature Scaling
#  4. Assumes Linearity
#  5. Unsupervised Nature
#  6. Not Ideal for Sparse or Categorical Data
#  7. Computational Cost

# %% [markdown]
# #18. How do KNN and PCA complement each other?
#  - K-Nearest Neighbors (KNN) and Principal Component Analysis (PCA) complement each other beautifully—like a minimalist designer teaming up with a brilliant detail-oriented craftsman.
#
# Here’s why they work so well together:
#
#   **KNN’s Weakness Becomes PCA’s Strength**
#   KNN is a distance-based algorithm, which makes it:
#
#   - Sensitive to irrelevant features,
#   - Vulnerable to the curse of dimensionality, and
#   - Easily thrown off by unscaled or noisy data.

# %% [markdown]
# #19. How does KNN handle missing values in a dataset?
#  - How it worked:
#  1. Identify Missing Values Missing entries are typically marked as NaN in the dataset.
#
#  2. Find Nearest Neighbors For each data point with a missing value, KNN finds the k closest points based on the available (non-missing) features using a distance metric like Euclidean or Manhattan.
#  3. Impute the Missing Value
#     - For numerical features, the missing value is replaced with the mean or weighted mean of the corresponding feature values from the k neighbors.
#     - For categorical features, it can use the most frequent category among the neighbors (after encoding).

# %% [markdown]
# #20. What are the key differences between PCA and Linear Discriminant Analysis (LDA)?
#  - Differences between PCA and Linear Discriminant Analysis (LDA):
#  1. PCA :
#   - In Mathematical Objective, PCA Finds orthogonal axes (principal components) that capture the most variance in the data.
#   - In Output Components, PCA can return up to n components (where C is the number of classes).
#   - It captures directions of maximum spread.
#
#  2. Linear Discriminant Analysis (LDA):
#   - In Mathematical Objective, LDA finds axes that maximize the ratio of between-class variance to within-class variance.
#   - In Output Components, LDA can return at most C - 1 components (where C is the number of classes).
#   - It captures directions that best seperate classes.

# %% [markdown]
# #**Practical Questions:**

# %% [markdown]
# #21. Train a KNN Classifier on the Iris dataset and print model accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.91

# %% [markdown]
# #22. Train a KNN Regressor on a synthetic dataset and evaluate using Mean Squared Error (MSE).

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=200, n_features=5, noise=15, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_reg = KNeighborsRegressor(n_neighbors=5)
knn_reg.fit(X_train_scaled, y_train)

y_pred = knn_reg.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 1790.65

# %% [markdown]
# #23. Train a KNN Classifier using different distance metrics (Euclidean and Manhattan) and compare accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

metrics = ['euclidean', 'manhattan']
results = {}

for metric in metrics:
    knn = KNeighborsClassifier(n_neighbors=5, metric=metric)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    results[metric] = acc
    print(f"Accuracy using {metric} distance: {acc:.2f}")
# Out:
# Accuracy using euclidean distance: 0.91
# Accuracy using manhattan distance: 0.91

# %% [markdown]
# #24. Train a KNN Classifier with different values of K and visualize decision boundaries.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA

iris = load_iris()
X, y = iris.data, iris.target

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42, stratify=y)

h = .02
x_min, x_max = X_pca[:, 0].min() - 1, X_pca[:, 0].max() + 1
y_min, y_max = X_pca[:, 1].min() - 1, X_pca[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
grid = np.c_[xx.ravel(), yy.ravel()]

plt.figure(figsize=(15, 5))
for i, k in enumerate([1, 5, 15]):
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(X_train, y_train)
    Z = clf.predict(grid).reshape(xx.shape)

    plt.subplot(1, 3, i + 1)
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, edgecolor='k', cmap=plt.cm.Paired)
    plt.title(f"K = {k}")

plt.suptitle("Decision Boundaries for Different K Values")
plt.tight_layout()
plt.show()

# %% [markdown]
# #25. Apply Feature Scaling before training a KNN model and compare results with unscaled data.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

knn_unscaled = KNeighborsClassifier(n_neighbors=5)
knn_unscaled.fit(X_train, y_train)
y_pred_unscaled = knn_unscaled.predict(X_test)
acc_unscaled = accuracy_score(y_test, y_pred_unscaled)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_scaled = KNeighborsClassifier(n_neighbors=5)
knn_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = knn_scaled.predict(X_test_scaled)
acc_scaled = accuracy_score(y_test, y_pred_scaled)

print(f"Accuracy without Scaling: {acc_unscaled:.2f}")
print(f"Accuracy with Scaling:    {acc_scaled:.2f}")
# Out:
# Accuracy without Scaling: 0.98
# Accuracy with Scaling:    0.91

# %% [markdown]
# #26. Train a PCA model on synthetic data and print the explained variance ratio for each component.

# %%
from sklearn.datasets import make_classification
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

X, _ = make_classification(n_samples=200, n_features=10,
                           n_informative=5, n_redundant=2,
                           random_state=42)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio for each component:")
print(pd.Series(explained_variance).apply(lambda x: f"{x:.4f}"))
# Out:
# Explained Variance Ratio for each component:
# 0    0.2342
# 1    0.1775
# 2    0.1217
# 3    0.1168
# 4    0.1028
# 5    0.0957
# 6    0.0872
# 7    0.0641
# 8    0.0000
# 9    0.0000
# dtype: object

# %% [markdown]
# #27. Apply PCA before training a KNN Classifier and compare accuracy with and without PCA.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_plain = KNeighborsClassifier(n_neighbors=5)
knn_plain.fit(X_train_scaled, y_train)
y_pred_plain = knn_plain.predict(X_test_scaled)
acc_plain = accuracy_score(y_test, y_pred_plain)

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)
y_pred_pca = knn_pca.predict(X_test_pca)
acc_pca = accuracy_score(y_test, y_pred_pca)

print(f"Accuracy without PCA: {acc_plain:.2f}")
print(f"Accuracy with PCA (2 components): {acc_pca:.2f}")
# Out:
# Accuracy without PCA: 0.91
# Accuracy with PCA (2 components): 0.91

# %% [markdown]
# #28. Perform Hyperparameter Tuning on a KNN Classifier using GridSearchCV.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

param_grid = {
    'knn__n_neighbors': list(range(1, 31)),
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan']
}

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Best Hyperparameters: {grid_search.best_params_}")
print(f"Accuracy with Best Model: {accuracy:.2f}")
# Out:
# Best Hyperparameters: {'knn__metric': 'euclidean', 'knn__n_neighbors': 14, 'knn__weights': 'uniform'}
# Accuracy with Best Model: 0.96

# %% [markdown]
# #29. Train a KNN Classifier and check the number of misclassified samples.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)

misclassified = (y_test != y_pred).sum()
accuracy = accuracy_score(y_test, y_pred)

print(f"Total test samples: {len(y_test)}")
print(f"Misclassified samples: {misclassified}")
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Total test samples: 45
# Misclassified samples: 4
# Accuracy: 0.91

# %% [markdown]
# #30. Train a PCA model and visualize the cumulative explained variance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, _ = load_iris(return_X_y=True)
X_scaled = StandardScaler().fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='-')
plt.axhline(y=0.95, color='gray', linestyle='--', label='95% threshold')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA: Cumulative Explained Variance')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #31. Train a KNN Classifier using different values of the weights parameter (uniform vs. distance) and compare accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

weights_options = ['uniform', 'distance']
for weights in weights_options:
    knn = KNeighborsClassifier(n_neighbors=5, weights=weights)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    print(f"Accuracy with weights = '{weights}': {acc:.2f}")
# Out:
# Accuracy with weights = 'uniform': 0.91
# Accuracy with weights = 'distance': 0.93

# %% [markdown]
# #32. Train a KNN Regressor and analyze the effect of different K values on performance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=300, n_features=5, noise=20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

k_values = range(1, 31)
mse_values = []

for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

plt.figure(figsize=(8, 5))
plt.plot(k_values, mse_values, marker='o')
plt.title("KNN Regressor Performance vs. k")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Mean Squared Error (MSE)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #33. Implement KNN Imputation for handling missing values in a dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=300, n_features=5, noise=20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

k_values = range(1, 31)
mse_values = []

for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

plt.figure(figsize=(8, 5))
plt.plot(k_values, mse_values, marker='o')
plt.title("KNN Regressor Performance vs. k")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Mean Squared Error (MSE)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #34. Train a PCA model and visualize the data projection onto the first two principal components.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, y = load_iris(return_X_y=True)
X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Projection onto First Two Components')
plt.grid(True)
plt.colorbar(scatter, label='Target Class')
plt.tight_layout()
plt.show()

# %% [markdown]
# #35. Train a KNN Classifier using the KD Tree and Ball Tree algorithms and compare performance.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import time

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

algorithms = ['kd_tree', 'ball_tree']
results = {}

for algo in algorithms:
    knn = KNeighborsClassifier(n_neighbors=5, algorithm=algo)
    start = time.time()
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    end = time.time()
    acc = accuracy_score(y_test, y_pred)
    results[algo] = {'accuracy': acc, 'time': end - start}
    print(f"{algo.upper()} → Accuracy: {acc:.2f}, Time: {end - start:.6f} sec")
# Out:
# KD_TREE → Accuracy: 0.91, Time: 0.021609 sec
# BALL_TREE → Accuracy: 0.91, Time: 0.025205 sec

# %% [markdown]
# #36. Train a PCA model on a high-dimensional dataset and visualize the Scree plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, _ = make_classification(n_samples=300, n_features=50,
                           n_informative=20, n_redundant=10,
                           random_state=42)

X_scaled = StandardScaler().fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

explained_var = pca.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_var) + 1), cumulative_var, marker='o', label='Cumulative Explained Variance')
plt.bar(range(1, len(explained_var) + 1), explained_var, alpha=0.5, label='Individual Explained Variance')
plt.axhline(y=0.95, color='gray', linestyle='--', label='95% Threshold')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot: PCA on High-Dimensional Data')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #37. Train a KNN Classifier and evaluate performance using Precision, Recall, and F1-Score.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)
print("Classification Report:\n")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000        15
#            1      0.789     1.000     0.882        15
#            2      1.000     0.733     0.846        15
#
#     accuracy                          0.911        45
#    macro avg      0.930     0.911     0.910        45
# weighted avg      0.930     0.911     0.910        45

# %% [markdown]
# #38. Train a PCA model and analyze the effect of different numbers of components on accuracy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

max_components = X.shape[1]
accuracies = []

for n in range(1, max_components + 1):
    pca = PCA(n_components=n)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)

    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train_pca, y_train)
    y_pred = knn.predict(X_test_pca)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

plt.figure(figsize=(8, 5))
plt.plot(range(1, max_components + 1), accuracies, marker='o')
plt.title("KNN Accuracy vs. Number of PCA Components")
plt.xlabel("Number of Principal Components")
plt.ylabel("Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #39. Train a KNN Classifier with different leaf_size values and compare accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

leaf_sizes = range(5, 55, 5)
accuracies = []

for leaf in leaf_sizes:
    knn = KNeighborsClassifier(n_neighbors=5, algorithm='kd_tree', leaf_size=leaf)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    print(f"leaf_size = {leaf:2d} → Accuracy: {acc:.2f}")

plt.figure(figsize=(8, 5))
plt.plot(leaf_sizes, accuracies, marker='o')
plt.title("KNN Accuracy vs. leaf_size (KD Tree)")
plt.xlabel("leaf_size")
plt.ylabel("Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# leaf_size =  5 → Accuracy: 0.91
# leaf_size = 10 → Accuracy: 0.91
# leaf_size = 15 → Accuracy: 0.91
# leaf_size = 20 → Accuracy: 0.91
# leaf_size = 25 → Accuracy: 0.91
# leaf_size = 30 → Accuracy: 0.91
# leaf_size = 35 → Accuracy: 0.91
# leaf_size = 40 → Accuracy: 0.91
# leaf_size = 45 → Accuracy: 0.91
# leaf_size = 50 → Accuracy: 0.91

# %% [markdown]
# #40. Train a PCA model and visualize how data points are transformed before and after PCA.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, y = load_iris(return_X_y=True)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.xlabel('Original Feature 1')
plt.ylabel('Original Feature 2')
plt.title('Original Scaled Data (First Two Features)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA-Transformed Data')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #41. Train a KNN Classifier on a real-world dataset (Wine dataset) and print classification report.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

X, y = load_wine(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_pred = knn.predict(X_test_scaled)
print("Classification Report:\n")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000        18
#            1      1.000     0.857     0.923        21
#            2      0.833     1.000     0.909        15
#
#     accuracy                          0.944        54
#    macro avg      0.944     0.952     0.944        54
# weighted avg      0.954     0.944     0.945        54

# %% [markdown]
# #42. Train a KNN Regressor and analyze the effect of different distance metrics on prediction error.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

X, y = make_regression(n_samples=300, n_features=5, noise=20, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

metrics = {
    'euclidean': 2,
    'manhattan': 1,
    'chebyshev': np.inf
}

mse_results = {}

for name, p in metrics.items():
    knn = KNeighborsRegressor(n_neighbors=5, metric='minkowski', p=p)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    mse_results[name] = mse
    print(f"{name.capitalize()} Distance → MSE: {mse:.2f}")

plt.figure(figsize=(8, 5))
plt.bar(mse_results.keys(), mse_results.values(), color='skyblue')
plt.title("KNN Regression: MSE by Distance Metric")
plt.ylabel("Mean Squared Error")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Euclidean Distance → MSE: 1743.62
# Manhattan Distance → MSE: 1718.09
# Chebyshev Distance → MSE: 1868.56

# %% [markdown]
# #43. Train a KNN Classifier and evaluate using ROC-AUC score.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

X, y = load_breast_cancer(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_proba = knn.predict_proba(X_test_scaled)[:, 1]

roc_auc = roc_auc_score(y_test, y_proba)
print(f"ROC-AUC Score: {roc_auc:.3f}")

fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f'KNN (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN Classifier')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ROC-AUC Score: 0.983

# %% [markdown]
# #44. Train a PCA model and visualize the variance captured by each principal component.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, _ = load_wine(return_X_y=True)
X_scaled = StandardScaler().fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

explained_var = pca.explained_variance_ratio_
components = np.arange(1, len(explained_var) + 1)

plt.figure(figsize=(8, 5))
plt.bar(components, explained_var, alpha=0.7, label='Individual')
plt.plot(components, np.cumsum(explained_var), marker='o', color='red', label='Cumulative')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Variance Captured by Each Principal Component')
plt.xticks(components)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #45. Train a KNN Classifier and perform feature selection before training.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

X, y = load_wine(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

selector = SelectKBest(score_func=f_classif, k=5)
X_train_selected = selector.fit_transform(X_train_scaled, y_train)
X_test_selected = selector.transform(X_test_scaled)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_selected, y_train)

y_pred = knn.predict(X_test_selected)
print("Classification Report:\n")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0      0.947     1.000     0.973        18
#            1      1.000     0.857     0.923        21
#            2      0.882     1.000     0.938        15
#
#     accuracy                          0.944        54
#    macro avg      0.943     0.952     0.945        54
# weighted avg      0.950     0.944     0.944        54

# %% [markdown]
# #46. Train a PCA model and visualize the data reconstruction error after reducing dimensions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

X, _ = load_digits(return_X_y=True)
X_scaled = StandardScaler().fit_transform(X)

components_range = range(1, X.shape[1] + 1)
reconstruction_errors = []

for n in components_range:
    pca = PCA(n_components=n)
    X_pca = pca.fit_transform(X_scaled)
    X_reconstructed = pca.inverse_transform(X_pca)
    mse = mean_squared_error(X_scaled, X_reconstructed)
    reconstruction_errors.append(mse)

plt.figure(figsize=(8, 5))
plt.plot(components_range, reconstruction_errors, marker='o')
plt.title("PCA Reconstruction Error vs. Number of Components")
plt.xlabel("Number of Principal Components")
plt.ylabel("Mean Squared Reconstruction Error")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #47. Train a KNN Classifier and visualize the decision boundary.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

X, y = load_iris(return_X_y=True)
X = X[:, :2]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

h = 0.02
x_min, x_max = X_train_scaled[:, 0].min() - 1, X_train_scaled[:, 0].max() + 1
y_min, y_max = X_train_scaled[:, 1].min() - 1, X_train_scaled[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
grid = np.c_[xx.ravel(), yy.ravel()]
Z = knn.predict(grid).reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)
plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=y_train,
            edgecolor='k', cmap=plt.cm.Paired)
plt.title("KNN Decision Boundary (k=5)")
plt.xlabel("Sepal Length (scaled)")
plt.ylabel("Sepal Width (scaled)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #48. Train a PCA model and analyze the effect of different numbers of components on data variance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, _ = load_wine(return_X_y=True)
X_scaled = StandardScaler().fit_transform(X)

pca = PCA()
pca.fit(X_scaled)

explained_var = pca.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)
components = np.arange(1, len(explained_var) + 1)

plt.figure(figsize=(10, 6))
plt.bar(components, explained_var, alpha=0.6, label='Individual Explained Variance')
plt.plot(components, cumulative_var, marker='o', color='red', label='Cumulative Explained Variance')
plt.axhline(y=0.95, color='gray', linestyle='--', label='95% Threshold')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Effect of PCA Components on Data Variance')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
